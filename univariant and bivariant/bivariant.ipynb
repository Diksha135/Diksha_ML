# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import pandas as pd
import numpy as np

# %%
sns.boxplot(iris)
# Out:
# <Axes: >

# %%
sns.kdeplot(iris)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.histplot(iris)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.relplot(iris)

# %%
tips=sns.load_dataset("tips")

# %%
sns.relplot(x=data['total_bill'], y=data['tip'], hue=data['sex'])

# %%
sns.scatterplot(data=iris, x="sepal_length", y="petal_length", hue="species", style="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(data=tips, x="size", y="tip",
                hue="smoker", size="total_bill")
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(data=titanic, x="embark_town", y="fare", hue="sex")
# Out:
# <Axes: xlabel='embark_town', ylabel='fare'>

# %%
sns.boxplot(data=titanic, x="pclass", y="fare", hue="survived")
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
sns.boxplot(data=tips, x="day", y="total_bill", hue="smoker")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.kdeplot(data=iris, x="petal_width", hue="species", fill=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %%
table = pd.crosstab(titanic["embark_town"], titanic["pclass"])

sns.heatmap(table, annot=True, cmap="coolwarm")
# Out:
# <Axes: xlabel='pclass', ylabel='embark_town'>

# %%
table = pd.crosstab(tips["day"], tips["time"])

sns.heatmap(table, annot=True, cmap="viridis")
# Out:
# <Axes: xlabel='time', ylabel='day'>

# %%
table = pd.crosstab(titanic["sibsp"], titanic["survived"])

sns.clustermap(table, cmap="coolwarm")

# %%
sns.pairplot(tips, hue="day")

# %%
sns.lineplot(data=titanic, x="pclass", y="fare")
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
data = pd.read_csv("train.csv")
sns.countplot(x="Survived", data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.histplot(data["Fare"], kde=True)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.boxplot(x="Pclass", y="Fare", data=data)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.countplot(x="Embarked", data=data)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>
